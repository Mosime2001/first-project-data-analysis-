# %% [markdown]
# <a href="https://colab.research.google.com/github/Mosime2001/first-project-data-analysis-/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Debt Analysis Project**
#
#
# Data Used Is From:
# *   World Bank Datasets
# *   Kaggle
#
# The Project Structure is as follows:
#
#
# 1.   objectives
# 2.   Data Collection
# 3.   Dta Cleaning and Processing
# 4.   Exploratory Data Analysis
# 5.   Data Analysis
# 6.   Visualization Comparison
# 7.   Interpretation Of Results

# %% [markdown]
# **Libraries Import**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_excel("/P_Data.xlsx")
#df2 = pd.read_csv("/DEBT- of GDP.csv")
#df3 = pd.read_csv("/GDP.csv")

# %% [markdown]
# **Read Data File: External Debt Stocks**

# %%
df.head()
# Out:
#    Time Time Code Counterpart-Area Name Counterpart-Area Code Country Name  \
# 0  2022    YR2022           Afghanistan                   625  Afghanistan
# 1  2022    YR2022           Afghanistan                   625      Albania
# 2  2022    YR2022           Afghanistan                   625      Algeria
# 3  2022    YR2022           Afghanistan                   625       Angola
# 4  2022    YR2022           Afghanistan                   625    Argentina
#
#   Country Code  \
# 0          AFG
# 1          ALB
# 2          DZA
# 3          AGO
# 4          ARG
#
#   External debt stocks, long-term (DOD, current US$) [DT.DOD.DLXF.CD]
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..

# %%
df.dtypes
# Out:
# Time                                                                   object
# Time Code                                                              object
# Counterpart-Area Name                                                  object
# Counterpart-Area Code                                                  object
# Country Name                                                           object
# Country Code                                                           object
# External debt stocks, long-term (DOD, current US$) [DT.DOD.DLXF.CD]    object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404685 entries, 0 to 404684
# Data columns (total 7 columns):
#  #   Column                                                               Non-Null Count   Dtype
# ---  ------                                                               --------------   -----
#  0   Time                                                                 404682 non-null  object
#  1   Time Code                                                            404680 non-null  object
#  2   Counterpart-Area Name                                                404680 non-null  object
#  3   Counterpart-Area Code                                                404680 non-null  object
#  4   Country Name                                                         404680 non-null  object
#  5   Country Code                                                         404680 non-null  object
# ...

# %%
df.describe()
# Out:
#           Time Time Code Counterpart-Area Name Counterpart-Area Code  \
# count   404682    404680                404680                404680
# unique      12        10                   302                   302
# top       2022    YR2022              Zimbabwe                   265
# freq     40468     40468                  1340                  1340
#
#        Country Name Country Code  \
# count        404680       404680
# unique          134          134
# top     Afghanistan          AFG
# freq           3020         3020
#
#        External debt stocks, long-term (DOD, current US$) [DT.DOD.DLXF.CD]
# count                                              404680
# unique                                               6696
# top                                                    ..
# freq                                               396396

# %%
df.shape
# Out:
# (404685, 7)

# %% [markdown]
# **Read Data File: Debt Of GDP**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df2 = pd.read_csv("/DEBT- of GDP.csv")
#df3 = pd.read_csv("/GDP.csv")

# %%
df2.head()
# Out:
#   DEBT (% of GDP)  1800  1801  1802  1803  1804  1805  1806  1807  1808  ...  \
# 0     Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1         Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2         Algeria   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3          Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4        Anguilla   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#     2006   2007   2008   2009   2010   2011   2012   2013   2014   2015
# 0  23.02  20.24  18.37  16.78   7.90   7.14   6.63   6.75   6.38   6.25
# 1  56.69  53.55  55.14  59.67  57.72  59.41  62.14  70.39  72.04  73.32
# 2  24.30  13.61   8.39  10.16  10.87   9.49   9.49   7.74   7.96   9.06
# 3  18.70  16.07  16.65  22.71  44.29  33.80  29.49  32.87  40.66  64.24
# 4  14.04  14.04  15.40  25.10  32.50  29.21  30.94  30.42  24.11  22.15
#
# [5 rows x 217 columns]

# %%
df2.dtypes
# Out:
# DEBT (% of GDP)     object
# 1800               float64
# 1801               float64
# 1802               float64
# 1803               float64
#                     ...
# 2011               float64
# 2012               float64
# 2013               float64
# 2014               float64
# 2015               float64
# Length: 217, dtype: object

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Columns: 217 entries, DEBT (% of GDP) to 2015
# dtypes: float64(216), object(1)
# memory usage: 329.0+ KB

# %%
df2.describe()
# Out:
#              1800      1801        1802        1803        1804        1805  \
# count    4.000000    4.0000    4.000000    4.000000    4.000000    4.000000
# mean    81.677500   81.0075   85.507500   85.910000   85.067500   82.787500
# std     72.091184   73.0218   78.402698   79.353498   78.292695   80.701447
# min     18.080000   15.7200   16.470000   15.800000   16.180000   13.900000
# 25%     30.267500   29.6175   29.497500   29.405000   29.095000   23.492500
# 50%     65.895000   65.4200   68.285000   68.585000   67.845000   64.090000
# 75%    117.305000  116.8100  124.295000  125.090000  123.817500  123.385000
# max    176.840000  177.4700  188.990000  190.670000  188.400000  189.070000
#
#              1806        1807        1808        1809  ...        2006  \
# count    4.000000    4.000000    4.000000    4.000000  ...  191.000000
# mean    82.487500   82.220000   81.607500   80.600000  ...   51.438586
# ...

# %%
df2.shape
# Out:
# (194, 217)

# %% [markdown]
# **Read Data File: GDP**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt

plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df3 = pd.read_csv("/GDP.csv")

# %%
df3.head()
# Out:
#                        Country Country Code          1960          1961  \
# 0                        Aruba          ABW           NaN           NaN
# 1  Africa Eastern and Southern          AFE  2.112502e+10  2.161623e+10
# 2                  Afghanistan          AFG  5.377778e+08  5.488889e+08
# 3   Africa Western and Central          AFW  1.044764e+10  1.117321e+10
# 4                       Angola          AGO           NaN           NaN
#
#            1962          1963          1964          1965          1966  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  2.350628e+10  2.804836e+10  2.592067e+10  2.947210e+10  3.201437e+10
# 2  5.466667e+08  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09
# 3  1.199053e+10  1.272769e+10  1.389811e+10  1.492979e+10  1.591084e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            1967  ...          2013          2014          2015          2016  \
# ...

# %%
df3.dtypes
# Out:
# Country          object
# Country Code     object
# 1960            float64
# 1961            float64
# 1962            float64
#                  ...
# 2018            float64
# 2019            float64
# 2020            float64
# 2021            float64
# 2022            float64
# Length: 65, dtype: object

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       266 non-null    object
#  1   Country Code  266 non-null    object
#  2   1960          132 non-null    float64
#  3   1961          134 non-null    float64
#  4   1962          136 non-null    float64
#  5   1963          136 non-null    float64
#  6   1964          136 non-null    float64
#  7   1965          147 non-null    float64
#  8   1966          150 non-null    float64
#  9   1967          153 non-null    float64
#  10  1968          158 non-null    float64
#  11  1969          158 non-null    float64
#  12  1970          167 non-null    float64
#  13  1971          170 non-null    float64
#  14  1972          170 non-null    float64
#  15  1973          170 non-null    float64
#  16  1974          171 non-null    float64
# ...

# %%
df3.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  1.320000e+02  1.340000e+02  1.360000e+02  1.360000e+02  1.360000e+02
# mean   7.127083e+10  7.274846e+10  7.639516e+10  8.236303e+10  9.048173e+10
# std    2.135947e+11  2.223876e+11  2.370024e+11  2.549141e+11  2.788048e+11
# min    1.201203e+07  1.159202e+07  9.122751e+06  1.084010e+07  1.271247e+07
# 25%    5.288385e+08  5.361919e+08  5.429342e+08  5.687581e+08  5.731182e+08
# 50%    3.040214e+09  2.965945e+09  3.049474e+09  3.569338e+09  3.432187e+09
# 75%    3.103045e+10  3.128542e+10  3.161860e+10  3.617095e+10  3.401420e+10
# max    1.384857e+12  1.449221e+12  1.550815e+12  1.671447e+12  1.830492e+12
#
#                1965          1966          1967          1968          1969  \
# count  1.470000e+02  1.500000e+02  1.530000e+02  1.580000e+02  1.580000e+02
# mean   9.182705e+10  1.021722e+11  1.059782e+11  1.111099e+11  1.228651e+11
# ...

# %%
df3.shape
# Out:
# (266, 65)

# %% [markdown]
# ## **Cleaning Data**

# %%
df[df.duplicated() == True]
# Out:
#        Time Time Code Counterpart-Area Name Counterpart-Area Code  \
# 404681  NaN       NaN                   NaN                   NaN
# 404682  NaN       NaN                   NaN                   NaN
#
#        Country Name Country Code  \
# 404681          NaN          NaN
# 404682          NaN          NaN
#
#        External debt stocks, long-term (DOD, current US$) [DT.DOD.DLXF.CD]
# 404681                                                NaN
# 404682                                                NaN
